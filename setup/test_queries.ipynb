# %%
# from prettytable import PrettyTable
# from prettytable import DEFAULT
# PrettyTable.set_style(DEFAULT)

# %%
# insert records into the database 
import pandas as pd
import sqlite3 as sql
import os
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
cnn=sql.connect('airlines.db')

# %%
# %load_ext sql

# %%
# %sql sqlite:///airlines.db

# %%
# %%sql
# insert into aircrafts VALUES ('AC060', 350, 'Boeing', '2024-01-01');
# insert into aircrafts VALUES ('AC061', 350, 'Boeing', '2024-01-01');
# Out:
#  * sqlite:///airlines.db
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# select * from aircrafts Order by AcNumber Desc Limit 5;
# Out:
#  * sqlite:///airlines.db
# Done.
# [('AC061', 350, 'Boeing', '2024-01-01'),
#  ('AC061', 350, 'Boeing', '2024-01-01'),
#  ('AC060', 350, 'Boeing', '2024-01-01'),
#  ('AC060', 350, 'Boeing', '2024-01-01'),
#  ('AC050', 250, 'Boeing', '2018-10-30')]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='trigger';
# Out:
#  * sqlite:///airlines.db
# Done.
# [('InsertAircraftLog',),
#  ('InsertScheduleLog',),
#  ('InsertPassengerLog',),
#  ('updatePassengerLog',),
#  ('deletePassengerLog',),
#  ('insertTransactionLog',),
#  ('updateTransactionLog',)]

# %%
# %%sql
# select * from logs;
# Out:
#  * sqlite:///airlines.db
# Done.
# [(1, 'INSERT', '2024-12-04 20:02:03', 'Aircraft: AC060, 350, Boeing, 2024-01-01'),
#  (2, 'INSERT', '2024-12-04 20:02:03', 'Aircraft: AC061, 350, Boeing, 2024-01-01'),
#  (3, 'INSERT', '2024-12-04 20:04:17', 'Flight_Schedule: 22, 2024-12-09 14:04:00, 2024-12-09 14:04:00, 2024-12-09 14:04:00, AC005, 2'),
#  (4, 'UPDATE', '2024-12-04 20:16:25', 'Booking: Old: 10, 2024-04-23 00:00:00, 2024-10-19 00:00:00, 78, 36, 1, 38, 32, 47 | New: 10, 2024-04-23 00:00:00, 2024-10-19 00:00:00, 78, 36, 1, 38, 32, 48'),
#  (5, 'UPDATE', '2024-12-04 20:16:34', 'Booking: Old: 10, 2024-04-23 00:00:00, 2024-10-19 00:00:00, 78, 36, 1, 38, 32, 48 | New: 10, 2024-04-23 00:00:00, 2024-10-19 00:00:00, 78, 36, 1, 38, 44, 48'),
#  (6, 'INSERT', '2024-12-07 00:10:27', 'Aircraft: AC060, 350, Boeing, 2024-01-01'),
#  (7, 'INSERT', '2024-12-07 00:10:27', 'Aircraft: AC061, 350, Boeing, 2024-01-01')]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///airlines.db
# Done.
# [('sqlite_sequence',),
#  ('Aircrafts',),
#  ('AirFare',),
#  ('Branches',),
#  ('Charges',),
#  ('Contact_Details',),
#  ('Countries',),
#  ('Discounts',),
#  ('Employee',),
#  ('Flight_Schedule',),
#  ('Passengers',),
#  ('Route',),
#  ('State',),
#  ('Transactions',),
#  ('LOGS',)]

# %%
path=os.path.abspath(os.path.join(os.getcwd(),".."))
path=os.path.join(path,'data')
path
# Out:
# 'd:\\pythonProjects\\airlines_management\\data'

# %%
# %%sql
# select * from Aircrafts;
# Out:
#  * sqlite:///airlines.db
# Done.
# [('AC001', 150, 'Boeing', '2009-03-01'),
#  ('AC002', 200, 'Boeing', '2005-05-16'),
#  ('AC003', 150, 'Boeing', '2001-03-03'),
#  ('AC004', 150, 'Embraer', '2001-02-25'),
#  ('AC005', 300, 'Embraer', '2011-05-07'),
#  ('AC006', 300, 'Embraer', '2003-09-01'),
#  ('AC007', 150, 'Boeing', '2001-12-23'),
#  ('AC008', 300, 'Airbus', '2006-02-11'),
#  ('AC009', 250, 'Embraer', '2017-10-11'),
#  ('AC010', 150, 'Airbus', '2010-03-23'),
#  ('AC011', 150, 'Embraer', '2007-01-08'),
#  ('AC012', 200, 'Embraer', '2014-09-04'),
#  ('AC013', 200, 'Embraer', '2000-12-25'),
#  ('AC014', 200, 'Embraer', '2000-04-02'),
#  ('AC015', 300, 'Airbus', '2002-10-31'),
#  ('AC016', 200, 'Airbus', '2005-06-14'),
#  ('AC017', 250, 'Embraer', '2019-05-22'),
#  ('AC018', 150, 'Airbus', '2007-09-27'),
#  ('AC019', 250, 'Embraer', '2018-07-04'),
#  ('AC020', 200, 'Boeing', '2005-10-13'),
#  ('AC021', 200, 'Airbus', '2019-09-13'),
#  ('AC022', 250, 'Airbus', '2003-01-23'),
# ...

# %% [markdown]
# %%sql
# delete from Aircrafts where AcNumber='AC051';

# %%
# %%sql
# SELECT FlID,FlightDate,Departure,Arrival,Aircraft, Airport, Destination FROM Flight_Schedule f inner join AirFare a on f.NetFare=a.AfID inner join Route r on a.Route=r.RtID
# Out:
#  * sqlite:///airlines.db
# Done.
# [(1, '2025-05-27 18:00:00', '2025-05-27 18:00:00', '2025-05-27 23:00:00', 'AC001', 'JFK International', 'Singapore Changi'),
#  (2, '2025-07-06 08:00:00', '2025-07-06 08:00:00', '2025-07-06 17:00:00', 'AC007', 'JFK International', 'Singapore Changi'),
#  (3, '2025-05-02 10:00:00', '2025-05-02 10:00:00', '2025-05-02 16:00:00', 'AC006', 'JFK International', 'Frankfurt Airport'),
#  (4, '2024-11-19 21:00:00', '2024-11-19 21:00:00', '2024-11-20 04:00:00', 'AC008', 'JFK International', 'Frankfurt Airport'),
#  (5, '2025-08-21 19:00:00', '2025-08-21 19:00:00', '2025-08-22 02:00:00', 'AC001', 'Dallas/Fort Worth International', 'Toronto Pearson'),
#  (6, '2024-04-08 23:00:00', '2024-04-08 23:00:00', '2024-04-09 04:00:00', 'AC009', 'JFK International', 'Frankfurt Airport'),
#  (7, '2025-06-04 08:00:00', '2025-06-04 08:00:00', '2025-06-04 17:00:00', 'AC001', 'Orlando International', 'Paris Charles de Gaulle'),
# ...

# %%
# %%sql
# select * from transactions;
# Out:
#  * sqlite:///airlines.db
# Done.
# [(1, '2024-11-01 00:00:00', '2024-05-21 00:00:00', 28, 28, 1, 60, 33, 29),
#  (2, '2024-11-19 00:00:00', '2024-07-08 00:00:00', 17, 28, 1, 3, 29, 28),
#  (3, '2024-04-14 00:00:00', '2024-03-19 00:00:00', 94, 27, 0, 77, 45, 16),
#  (4, '2024-03-15 00:00:00', '2024-04-26 00:00:00', 23, 26, 1, 1, 11, 36),
#  (5, '2024-11-05 00:00:00', '2024-11-10 00:00:00', 46, 19, 1, 93, 8, 29),
#  (6, '2024-08-06 00:00:00', '2024-02-05 00:00:00', 57, 10, 1, 65, 8, 50),
#  (7, '2024-03-19 00:00:00', '2024-06-15 00:00:00', 5, 9, 1, 73, 39, 33),
#  (8, '2024-01-03 00:00:00', '2024-08-18 00:00:00', 83, 38, 1, 79, 43, 38),
#  (9, '2024-09-20 00:00:00', '2024-06-09 00:00:00', 16, 39, 1, 9, 19, 19),
#  (10, '2024-04-23 00:00:00', '2024-10-19 00:00:00', 78, 36, 1, 38, 44, 48),
#  (11, '2024-11-03 00:00:00', '2024-07-06 00:00:00', 11, 11, 1, 7, 4, 36),
#  (12, '2024-02-22 00:00:00', '2024-06-07 00:00:00', 83, 29, 1, 1, 25, 36),
# ...

# %%
# %%sql
# select * from passengers where Nationality ='United States' and Age >50;
# Out:
#  * sqlite:///airlines.db
# Done.
# [(103, 'Peter Jones', '380 Broadway', 79, 'United States', 4),
#  (115, 'Brian Johnson', '443 Broadway', 56, 'United States', 16),
#  (120, 'Susan White', '957 Pine St', 58, 'United States', 21)]

# %%
# %%sql
# select * from logs where data like '%2024-01-01%';
# Out:
#  * sqlite:///airlines.db
# Done.
# []

# %%
# %%sql
# SELECT FlID,FlightDate,Departure,Arrival,Aircraft, Airport, Destination
#     FROM Flight_Schedule f inner join AirFare a on f.NetFare=a.AfID inner join Route r on a.Route=r.RtID
#         where FlightDate = '2024-12-07 11:00:00' and Airport like '%JFK%'
# Out:
#  * sqlite:///airlines.db
# Done.
# [(42, '2024-12-07 11:00:00', '2024-12-07 11:00:00', '2024-12-07 12:00:00', 'AC007', 'JFK International', 'Frankfurt Airport')]

# %%
# %%sql
# SELECT FlID,FlightDate,Departure,Arrival,Aircraft,
# Airport, Destination FROM Flight_Schedule f inner join AirFare a on f.NetFare=a.AfID inner join Route r on a.Route=r.RtID where Aircraft ='AC007' and Destination like '%Singapore%'
# Out:
#  * sqlite:///airlines.db
# Done.
# [(2, '2025-07-06 08:00:00', '2025-07-06 08:00:00', '2025-07-06 17:00:00', 'AC007', 'JFK International', 'Singapore Changi'),
#  (124, '2024-12-08 18:00:00', '2024-12-08 18:00:00', '2024-12-08 23:00:00', 'AC007', 'JFK International', 'Singapore Changi'),
#  (138, '2024-12-06 18:00:00', '2024-12-06 18:00:00', '2024-12-06 23:00:00', 'AC007', 'JFK International', 'Singapore Changi')]

# %%
# %%sql
# SELECT FlID,FlightDate,Departure,Arrival,Aircraft,
# Airport, Destination FROM Flight_Schedule f inner join AirFare a on f.NetFare=a.AfID inner join Route r on a.Route=r.RtID where Aircraft ='AC007' and Destination like '%Singapore%'
# Out:
#  * sqlite:///airlines.db
# Done.
# [(2, '2025-07-06 08:00:00', '2025-07-06 08:00:00', '2025-07-06 17:00:00', 'AC007', 'JFK International', 'Singapore Changi'),
#  (124, '2024-12-08 18:00:00', '2024-12-08 18:00:00', '2024-12-08 23:00:00', 'AC007', 'JFK International', 'Singapore Changi'),
#  (138, '2024-12-06 18:00:00', '2024-12-06 18:00:00', '2024-12-06 23:00:00', 'AC007', 'JFK International', 'Singapore Changi')]

# %%
# %%sql
# SELECT rt.Airport, rt.Destination, COUNT(t.Passenger) AS TotalPassengers
# FROM Route rt
# JOIN Flight_Schedule fs ON rt.RtID = fs.FlID
# JOIN Transactions t ON fs.FlID = t.Flight
# GROUP BY rt.Airport, rt.Destination
# ORDER BY TotalPassengers DESC LIMIT 5;
# Out:
#  * sqlite:///airlines.db
# Done.
# [('Miami International', 'Paris Charles de Gaulle', 10),
#  ('Orlando International', 'Paris Charles de Gaulle', 7),
#  ('Orlando International', 'Hong Kong International', 6),
#  ('Seattle-Tacoma International', 'Sydney Kingsford Smith', 6),
#  ('Dallas/Fort Worth International', 'Toronto Pearson', 5)]

# %% [markdown]
# # total revenue

# %%
# %%sql
#
# SELECT rt.Airport, rt.Destination,
#        SUM(t.Charges + af.Fare - d.Amount) AS TotalRevenue
# FROM Transactions t
# JOIN Flight_Schedule fs ON t.Flight = fs.FlID
# JOIN Route rt ON fs.FlID = rt.RtID
# JOIN AirFare af ON rt.RtID = af.Route
# JOIN Discounts d ON t.Discount = d.DiID
# GROUP BY rt.Airport, rt.Destination
# ORDER BY TotalRevenue ;
# Out:
#  * sqlite:///airlines.db
# Done.
# [('Denver International', 'Dubai International', 952.1299999999999),
#  ('Miami International', 'Paris Charles de Gaulle', 1705.5500000000002),
#  ('JFK International', 'Singapore Changi', 1807.9),
#  ('Orlando International', 'London Heathrow', 2028.7600000000002),
#  ('Dallas/Fort Worth International', 'Toronto Pearson', 3238.26),
#  ('Orlando International', 'Paris Charles de Gaulle', 3552.4300000000003),
#  ('JFK International', 'Frankfurt Airport', 86087.72)]

# %% [markdown]
# Employees in High-Traffic States
# employees_in_states_query = """

# %% [markdown]
# # most loyal passenger

# %%
# %%sql
# SELECT p.Name, COUNT(t.TsID) AS BookingsCount
# FROM Passengers p
# JOIN Transactions t ON p.PsID = t.Passenger
# GROUP BY p.Name
# ORDER BY BookingsCount DESC
# LIMIT 5;
# Out:
#  * sqlite:///airlines.db
# Done.
# [('Robert Moore', 1)]

# %%
# triggers

# %%
# %%sql
# CREATE TRIGGER InsertScheduleLog
# AFTER INSERT ON Flight_Schedule
# FOR EACH ROW
# BEGIN
#     INSERT INTO LOGS (OPERATION, DATA)
#     VALUES (
#         'INSERT',
#           'Flight_Schedule: ' || NEW.FlID || ', ' || NEW.FlightDate || ', ' || NEW.Departure || ', ' ||
#         NEW.Arrival || ', ' || NEW.Aircraft || ', ' || NEW.NetFare
#         );
# END;
# Out:
#   Cell In[45], line 1
#     CREATE TRIGGER InsertScheduleLog
#            ^
# SyntaxError: invalid syntax

# %%
# %%sql
# CREATE TRIGGER updatePassengerLog
# AFTER UPDATE ON Passengers
# FOR EACH ROW
# BEGIN
#     INSERT INTO LOGS (OPERATION, DATA)
#     VALUES (
#         'UPDATE',
#         'Passengers: ' || 'Old PsID: ' || OLD.PsID || ', New PsID: ' || NEW.PsID || ', ' ||
#         'Old Name: ' || OLD.Name || ', New Name: ' || NEW.Name || ', ' ||
#         'Old Address: ' || OLD.Address || ', New Address: ' || NEW.Address || ', ' ||
#         'Old Age: ' || OLD.Age || ', New Age: ' || NEW.Age || ', ' ||
#         'Old Nationality: ' || OLD.Nationality || ', New Nationality: ' || NEW.Nationality || ', ' ||
#         'Old Contacts: ' || OLD.Contacts || ', New Contacts: ' || NEW.Contacts
#     );
# END;
# Out:
#   Cell In[46], line 1
#     CREATE TRIGGER updatePassengerLog
#            ^
# SyntaxError: invalid syntax

# %%
# %%sql
# CREATE TRIGGER IF NOT EXISTS deletePassengerLog
# AFTER DELETE ON Passengers
# FOR EACH ROW
# BEGIN
#     INSERT INTO LOGS (OPERATION, DATA)
#     VALUES (
#         'DELETE',
#         'Passengers: ' || OLD.PsID || ', Name: ' || OLD.Name || ', Address: ' || OLD.Address || ', ' ||
#         'Age: ' || OLD.Age || ', Nationality: ' || OLD.Nationality || ', Contacts: ' || OLD.Contacts
#     );
# END;

# %%
# %%sql
# CREATE TRIGGER IF NOT EXISTS updateTransactionLog
# AFTER UPDATE ON Transactions
# FOR EACH ROW
# BEGIN
#     INSERT INTO LOGS (OPERATION, DATA)
#     VALUES (
#         'UPDATE',
#         'Booking: ' || 'Old: ' || OLD.TsID || ', ' || OLD.BookingDate || ', ' || OLD.DepartureDate || ', ' ||
#         OLD.Passenger || ', ' || OLD.Flight || ', ' || OLD.Type || ', ' ||
#         OLD.Employee || ', ' || OLD.Charges || ', ' || OLD.Discount || ' | ' ||
#         'New: ' || NEW.TsID || ', ' || NEW.BookingDate || ', ' || NEW.DepartureDate || ', ' ||
#         NEW.Passenger || ', ' || NEW.Flight || ', ' || NEW.Type || ', ' ||
#         NEW.Employee || ', ' || NEW.Charges || ', ' || NEW.Discount
#     );
# END;
# Out:
#   Cell In[47], line 1
#     CREATE TRIGGER IF NOT EXISTS updateTransactionLog
#            ^
# SyntaxError: invalid syntax

# %%
# %%sql
# SELECT p.Nationality, AVG(d.Amount) AS AvgDiscount
# FROM Passengers p
# JOIN Transactions t ON p.PsID = t.Passenger
# JOIN Discounts d ON t.Discount = d.DiID
# GROUP BY p.Nationality;
# Out:
#  * sqlite:///airlines.db
# Done.
# [('United States', 25.0)]

# %%
# %%sql
# SELECT br.State as StateID, COUNT(fs.FlID) AS FlightsCount
# FROM Branches br
# JOIN Flight_Schedule fs ON br.BrID = fs.FlID
# GROUP BY br.State
# ORDER BY FlightsCount DESC
# LIMIT 3;
# Out:
#  * sqlite:///airlines.db
# Done.
# [(9, 2), (2, 2), (17, 1)]
